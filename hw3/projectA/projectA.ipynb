# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np

# 데이터셋 준비 (Fashion-MNIST)
transform = transforms.ToTensor()
train_data = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
test_data = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=1000)

# 공통 모델 정의 (MLP 구조)
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(28*28, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 10)  # logits 출력
        )

    def forward(self, x):
        x = x.view(-1, 28*28)
        return self.model(x)

# 학습 함수
def train(model, loss_fn, optimizer, epochs=40, use_softmax=False, tag='', loader=None):
    model.train()
    train_losses, test_accuracies = [], []

    for epoch in range(epochs):
        total_loss = 0
        for data, target in loader:
            optimizer.zero_grad()
            output = model(data)

            if use_softmax:
                output = torch.softmax(output, dim=1)
                target_onehot = torch.nn.functional.one_hot(target, num_classes=10).float()
                loss = loss_fn(output, target_onehot)
            else:
                loss = loss_fn(output, target)

            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        train_losses.append(total_loss / len(loader))
        acc = evaluate(model)
        test_accuracies.append(acc)

        print(f"[{tag}] Epoch {epoch+1}: Loss={total_loss:.4f}, Accuracy={acc:.2f}%")

        # 시각화 (초기/중반/후반)
        if epoch in [0, 20, epochs-1]:
            print(f"[{tag}] Gradient Flow at Epoch {epoch}")
            visualize_grad_flow(model)

            print(f"[{tag}] Activation Distribution at Epoch {epoch}")
            visualize_hidden_activations(epoch, model, loader, layer_idx=1)
            visualize_hidden_activations(epoch, model, loader, layer_idx=3)

    return train_losses, test_accuracies


# 평가 함수
def evaluate(model):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = model(data)
            preds = torch.argmax(output, dim=1)
            correct += (preds == target).sum().item()
            total += target.size(0)
    return 100 * correct / total

#중간 레이어 활성화값 분포
def visualize_hidden_activations(epoch, model, loader, layer_idx):
    model.eval()
    activations = []
    with torch.no_grad():
        for data, _ in loader:
            x = data.view(-1, 28*28)
            for i, layer in enumerate(model.model):
                x = layer(x)
                if i == layer_idx:
                    activations.append(x.cpu().numpy())
                    break
    activations = np.concatenate(activations, axis=0)
    plt.hist(activations.flatten(), bins=100)
    plt.title(f'Layer {layer_idx} activation histogram at epoch {epoch}')
    plt.show()

# Dead ReLU 비율 히트맵
def dead_relu_ratio(tensor):
    return (tensor <= 0).sum().item() / tensor.numel()

def visualize_dead_relu(model, loader):
    model.eval()
    with torch.no_grad():
        for data, _ in loader:
            x = data.view(-1, 28*28)
            ratios = []
            for layer in model.model:
                x = layer(x)
                if isinstance(layer, nn.ReLU):
                    ratios.append(dead_relu_ratio(x))
            break
    plt.imshow([ratios], cmap="Reds", aspect='auto')
    plt.title("Dead ReLU Ratios per Layer")
    plt.colorbar(label="Ratio of inactive neurons")
    plt.yticks([])
    plt.xticks(ticks=range(len(ratios)), labels=[f"ReLU {i+1}" for i in range(len(ratios))])
    plt.show()

# Gradient 흐름 시각화 (Vanishing 여부)
def visualize_grad_flow(model):
    ave_grads = []
    for name, param in model.named_parameters():
        if param.requires_grad and param.grad is not None:
            ave_grads.append(param.grad.abs().mean().item())
    plt.plot(ave_grads, marker='o')
    plt.title("Average Gradient Flow per Layer")
    plt.xlabel("Layer")
    plt.ylabel("Avg |gradient|")
    plt.grid(True)
    plt.show()

# CrossEntropy 모델 학습
model_ce = MLP()
loss_fn_ce = nn.CrossEntropyLoss()
optimizer_ce = optim.Adam(model_ce.parameters(), lr=0.001)
losses_ce, accs_ce = train(model_ce, loss_fn_ce, optimizer_ce, tag='CrossEntropy', loader=train_loader)

# MSE 모델 학습
model_mse = MLP()
loss_fn_mse = nn.MSELoss()
optimizer_mse = optim.Adam(model_mse.parameters(), lr=0.001)
losses_mse, accs_mse = train(model_mse, loss_fn_mse, optimizer_mse, use_softmax=True, tag='MSE', loader=train_loader)

# 그래프 시각화 (MSE)
# plt.figure(figsize=(12, 5))
# plt.subplot(1, 2, 1)
# plt.plot(losses_ce, label='CrossEntropy')
# plt.plot(losses_mse, label='MSE (with softmax)')
# plt.title("Loss vs Epoch")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.legend()
epochs = range(1, len(losses_ce)+1)

plt.figure(figsize=(14, 5))

# 1. Loss vs Epoch
plt.subplot(1, 2, 1)
plt.plot(epochs, losses_ce, label='CrossEntropy', color='blue')
plt.plot(epochs, losses_mse, label='MSE (with softmax)', color='orange')
plt.title("Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

# 2. Accuracy vs Epoch
plt.subplot(1, 2, 2)
plt.plot(epochs, accs_ce, label='CrossEntropy', color='blue')
plt.plot(epochs, accs_mse, label='MSE (with softmax)', color='orange')
plt.title("Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

print("\n [Dead ReLU 비율] CrossEntropy 모델")
visualize_dead_relu(model_ce, train_loader)
# Out:
# [CrossEntropy] Epoch 1: Loss=493.5713, Accuracy=84.28%
# [CrossEntropy] Gradient Flow at Epoch 0
# [CrossEntropy] Activation Distribution at Epoch 0
# [CrossEntropy] Epoch 2: Loss=346.7841, Accuracy=83.60%
# [CrossEntropy] Epoch 3: Loss=312.6170, Accuracy=87.24%
# [CrossEntropy] Epoch 4: Loss=290.0753, Accuracy=87.01%
# [CrossEntropy] Epoch 5: Loss=270.9986, Accuracy=86.77%
# [CrossEntropy] Epoch 6: Loss=255.2028, Accuracy=86.19%
# [CrossEntropy] Epoch 7: Loss=246.0961, Accuracy=88.18%
# [CrossEntropy] Epoch 8: Loss=233.8830, Accuracy=88.04%
# [CrossEntropy] Epoch 9: Loss=223.8335, Accuracy=88.50%
# [CrossEntropy] Epoch 10: Loss=215.3764, Accuracy=88.41%
# [CrossEntropy] Epoch 11: Loss=205.2305, Accuracy=88.88%
# [CrossEntropy] Epoch 12: Loss=197.5493, Accuracy=88.94%
# [CrossEntropy] Epoch 13: Loss=190.8067, Accuracy=88.83%
# [CrossEntropy] Epoch 14: Loss=184.6361, Accuracy=88.98%
# [CrossEntropy] Epoch 15: Loss=177.0387, Accuracy=88.85%
# [CrossEntropy] Epoch 16: Loss=169.1323, Accuracy=89.33%
# [CrossEntropy] Epoch 17: Loss=165.3232, Accuracy=88.36%
# [CrossEntropy] Epoch 18: Loss=159.0758, Accuracy=88.91%
# [CrossEntropy] Epoch 19: Loss=157.6245, Accuracy=89.17%
# [CrossEntropy] Epoch 20: Loss=148.4425, Accuracy=89.43%
# [CrossEntropy] Epoch 21: Loss=143.3188, Accuracy=89.42%
# [CrossEntropy] Gradient Flow at Epoch 20
# [CrossEntropy] Activation Distribution at Epoch 20
# [CrossEntropy] Epoch 22: Loss=138.6379, Accuracy=89.22%
# [CrossEntropy] Epoch 23: Loss=136.5892, Accuracy=89.34%
# [CrossEntropy] Epoch 24: Loss=132.6604, Accuracy=89.24%
# [CrossEntropy] Epoch 25: Loss=126.4267, Accuracy=89.10%
# [CrossEntropy] Epoch 26: Loss=123.1761, Accuracy=89.32%
# [CrossEntropy] Epoch 27: Loss=120.2872, Accuracy=89.29%
# [CrossEntropy] Epoch 28: Loss=118.1400, Accuracy=89.00%
# [CrossEntropy] Epoch 29: Loss=110.8204, Accuracy=87.70%
# [CrossEntropy] Epoch 30: Loss=111.1240, Accuracy=88.79%
# [CrossEntropy] Epoch 31: Loss=106.4497, Accuracy=89.74%
# [CrossEntropy] Epoch 32: Loss=103.6604, Accuracy=88.34%
# [CrossEntropy] Epoch 33: Loss=101.4760, Accuracy=88.82%
# [CrossEntropy] Epoch 34: Loss=97.1263, Accuracy=89.16%
# [CrossEntropy] Epoch 35: Loss=93.3734, Accuracy=89.09%
# [CrossEntropy] Epoch 36: Loss=95.1246, Accuracy=89.33%
# [CrossEntropy] Epoch 37: Loss=94.6465, Accuracy=89.42%
# [CrossEntropy] Epoch 38: Loss=86.3509, Accuracy=89.67%
# [CrossEntropy] Epoch 39: Loss=85.1983, Accuracy=89.50%
# [CrossEntropy] Epoch 40: Loss=84.1701, Accuracy=89.33%
# [CrossEntropy] Gradient Flow at Epoch 39
# [CrossEntropy] Activation Distribution at Epoch 39
# [MSE] Epoch 1: Loss=25.2443, Accuracy=85.01%
# [MSE] Gradient Flow at Epoch 0
# [MSE] Activation Distribution at Epoch 0
# [MSE] Epoch 2: Loss=18.5438, Accuracy=84.98%
# [MSE] Epoch 3: Loss=16.7661, Accuracy=86.60%
# [MSE] Epoch 4: Loss=15.7881, Accuracy=86.95%
# [MSE] Epoch 5: Loss=14.9323, Accuracy=86.81%
# [MSE] Epoch 6: Loss=14.2416, Accuracy=88.45%
# [MSE] Epoch 7: Loss=13.8767, Accuracy=88.01%
# [MSE] Epoch 8: Loss=13.2673, Accuracy=87.93%
# [MSE] Epoch 9: Loss=12.8369, Accuracy=88.10%
# [MSE] Epoch 10: Loss=12.4551, Accuracy=88.52%
# [MSE] Epoch 11: Loss=12.1393, Accuracy=88.30%
# [MSE] Epoch 12: Loss=11.6783, Accuracy=88.75%
# [MSE] Epoch 13: Loss=11.4117, Accuracy=88.65%
# [MSE] Epoch 14: Loss=11.2785, Accuracy=87.78%
# [MSE] Epoch 15: Loss=10.9342, Accuracy=88.94%
# [MSE] Epoch 16: Loss=10.4109, Accuracy=89.21%
# [MSE] Epoch 17: Loss=10.2708, Accuracy=88.90%
# [MSE] Epoch 18: Loss=10.0868, Accuracy=88.93%
# [MSE] Epoch 19: Loss=9.7876, Accuracy=88.40%
# [MSE] Epoch 20: Loss=9.5499, Accuracy=88.83%
# [MSE] Epoch 21: Loss=9.2220, Accuracy=88.81%
# [MSE] Gradient Flow at Epoch 20
# [MSE] Activation Distribution at Epoch 20
# [MSE] Epoch 22: Loss=9.0944, Accuracy=88.19%
# [MSE] Epoch 23: Loss=8.8431, Accuracy=89.22%
# [MSE] Epoch 24: Loss=8.7725, Accuracy=88.73%
# [MSE] Epoch 25: Loss=8.5594, Accuracy=89.07%
# [MSE] Epoch 26: Loss=8.4436, Accuracy=89.05%
# [MSE] Epoch 27: Loss=8.2292, Accuracy=89.26%
# [MSE] Epoch 28: Loss=8.0774, Accuracy=89.32%
# [MSE] Epoch 29: Loss=7.6915, Accuracy=89.22%
# [MSE] Epoch 30: Loss=7.8252, Accuracy=89.32%
# [MSE] Epoch 31: Loss=7.6912, Accuracy=89.12%
# [MSE] Epoch 32: Loss=7.3763, Accuracy=88.68%
# [MSE] Epoch 33: Loss=7.3285, Accuracy=89.08%
# [MSE] Epoch 34: Loss=7.2607, Accuracy=89.46%
# [MSE] Epoch 35: Loss=7.2201, Accuracy=89.25%
# [MSE] Epoch 36: Loss=6.9147, Accuracy=88.78%
# [MSE] Epoch 37: Loss=6.7145, Accuracy=89.49%
# [MSE] Epoch 38: Loss=6.6686, Accuracy=88.95%
# [MSE] Epoch 39: Loss=6.7518, Accuracy=89.59%
# [MSE] Epoch 40: Loss=6.5664, Accuracy=89.46%
# [MSE] Gradient Flow at Epoch 39
# [MSE] Activation Distribution at Epoch 39
#  [Dead ReLU 비율] CrossEntropy 모델

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np

# 데이터셋 준비 (Fashion-MNIST)
transform = transforms.ToTensor()
train_data = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
test_data = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=1000)

# 공통 모델 정의 (MLP 구조)
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(28*28, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 10)  # logits 출력
        )

    def forward(self, x):
        x = x.view(-1, 28*28)
        return self.model(x)

# 학습 함수
def train(model, loss_fn, optimizer, epochs=40, use_softmax=False, tag='', loader=None):
    model.train()
    train_losses, test_accuracies = [], []

    for epoch in range(epochs):
        total_loss = 0
        for data, target in loader:
            optimizer.zero_grad()
            output = model(data)

            if use_softmax:
                output = torch.softmax(output, dim=1)
                target_onehot = torch.nn.functional.one_hot(target, num_classes=10).float()
                loss = loss_fn(output, target_onehot)
            else:
                loss = loss_fn(output, target)

            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        train_losses.append(total_loss / len(loader))
        acc = evaluate(model)
        test_accuracies.append(acc)

        print(f"[{tag}] Epoch {epoch+1}: Loss={total_loss:.4f}, Accuracy={acc:.2f}%")

        # 시각화 (초기/중반/후반)
        if epoch in [0, 20, epochs-1]:
            print(f"[{tag}] Gradient Flow at Epoch {epoch}")
            visualize_grad_flow(model)

            print(f"[{tag}] Activation Distribution at Epoch {epoch}")
            visualize_hidden_activations(epoch, model, loader, layer_idx=1)
            visualize_hidden_activations(epoch, model, loader, layer_idx=3)

            print(f"[{tag}] Gradient Histogram at Epoch {epoch}")
            visualize_grad_flow_histogram(model)

    return train_losses, test_accuracies


# 평가 함수
def evaluate(model):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = model(data)
            preds = torch.argmax(output, dim=1)
            correct += (preds == target).sum().item()
            total += target.size(0)
    return 100 * correct / total

#중간 레이어 활성화값 분포
def visualize_hidden_activations(epoch, model, loader, layer_idx):
    model.eval()
    activations = []
    with torch.no_grad():
        for data, _ in loader:
            x = data.view(-1, 28*28)
            for i, layer in enumerate(model.model):
                x = layer(x)
                if i == layer_idx:
                    activations.append(x.cpu().numpy())
                    break
    activations = np.concatenate(activations, axis=0)
    plt.hist(activations.flatten(), bins=100)
    plt.title(f'Layer {layer_idx} activation histogram at epoch {epoch}')
    plt.show()

# Dead ReLU 비율 히트맵
def dead_relu_ratio(tensor):
    return (tensor <= 0).sum().item() / tensor.numel()

def visualize_dead_relu(model, loader):
    model.eval()
    with torch.no_grad():
        for data, _ in loader:
            x = data.view(-1, 28*28)
            ratios = []
            for layer in model.model:
                x = layer(x)
                if isinstance(layer, nn.ReLU):
                    ratios.append(dead_relu_ratio(x))
            break
    plt.imshow([ratios], cmap="Reds", aspect='auto')
    plt.title("Dead ReLU Ratios per Layer")
    plt.colorbar(label="Ratio of inactive neurons")
    plt.yticks([])
    plt.xticks(ticks=range(len(ratios)), labels=[f"ReLU {i+1}" for i in range(len(ratios))])
    plt.show()

# Gradient 흐름 시각화 (Vanishing 여부)
def visualize_grad_flow(model):
    ave_grads = []
    for name, param in model.named_parameters():
        if param.requires_grad and param.grad is not None:
            ave_grads.append(param.grad.abs().mean().item())
    plt.plot(ave_grads, marker='o')
    plt.title("Average Gradient Flow per Layer")
    plt.xlabel("Layer")
    plt.ylabel("Avg |gradient|")
    plt.grid(True)
    plt.show()

def visualize_grad_flow_histogram(model):
    for name, param in model.named_parameters():
        if param.requires_grad and param.grad is not None:
            grads = param.grad.detach().cpu().numpy().flatten()
            plt.figure(figsize=(6, 3))
            plt.hist(grads, bins=100, alpha=0.75, color='skyblue')
            plt.title(f"Gradient Histogram: {name}")
            plt.xlabel("Gradient Value")
            plt.ylabel("Frequency")
            plt.grid(True)
            plt.tight_layout()
            plt.show()


# CrossEntropy 모델 학습
model_ce = MLP()
loss_fn_ce = nn.CrossEntropyLoss()
optimizer_ce = optim.Adam(model_ce.parameters(), lr=0.001)
losses_ce, accs_ce = train(model_ce, loss_fn_ce, optimizer_ce, tag='CrossEntropy', loader=train_loader)

# MSE 모델 학습
model_mse = MLP()
loss_fn_mse = nn.MSELoss()
optimizer_mse = optim.Adam(model_mse.parameters(), lr=0.001)
losses_mse, accs_mse = train(model_mse, loss_fn_mse, optimizer_mse, use_softmax=True, tag='MSE', loader=train_loader)

# 그래프 시각화 (MSE)
# plt.figure(figsize=(12, 5))
# plt.subplot(1, 2, 1)
# plt.plot(losses_ce, label='CrossEntropy')
# plt.plot(losses_mse, label='MSE (with softmax)')
# plt.title("Loss vs Epoch")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.legend()
epochs = range(1, len(losses_ce)+1)

plt.figure(figsize=(14, 5))

# 🔹 Loss 그래프
plt.subplot(1, 2, 1)
plt.plot(epochs, losses_ce, label='CrossEntropy', color='blue')
plt.plot(epochs, losses_mse, label='MSE (with softmax)', color='orange')
plt.title("Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

print("\n [Dead ReLU 비율] MSE 모델")
visualize_dead_relu(model_mse, train_loader)


# 그래프 시각화 (CrossEntropy)
plt.subplot(1, 2, 2)
plt.plot(accs_ce, label='CrossEntropy')
plt.plot(accs_mse, label='MSE (with softmax)')
plt.title("Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.tight_layout()
plt.show()

print("\n [Dead ReLU 비율] CrossEntropy 모델")
visualize_dead_relu(model_ce, train_loader)
# Out:
# [CrossEntropy] Epoch 1: Loss=486.9062, Accuracy=83.33%
# [CrossEntropy] Gradient Flow at Epoch 0
# [CrossEntropy] Activation Distribution at Epoch 0
# [CrossEntropy] Gradient Histogram at Epoch 0
# [CrossEntropy] Epoch 2: Loss=346.8540, Accuracy=85.96%
# [CrossEntropy] Epoch 3: Loss=309.8585, Accuracy=86.88%
# [CrossEntropy] Epoch 4: Loss=286.9031, Accuracy=87.60%
# [CrossEntropy] Epoch 5: Loss=271.6662, Accuracy=87.59%
# [CrossEntropy] Epoch 6: Loss=255.5379, Accuracy=87.42%
# [CrossEntropy] Epoch 7: Loss=243.6255, Accuracy=87.88%
# [CrossEntropy] Epoch 8: Loss=231.8165, Accuracy=88.20%
# [CrossEntropy] Epoch 9: Loss=224.0496, Accuracy=87.29%
# [CrossEntropy] Epoch 10: Loss=212.9913, Accuracy=88.65%
# [CrossEntropy] Epoch 11: Loss=204.8589, Accuracy=88.40%
# [CrossEntropy] Epoch 12: Loss=195.9855, Accuracy=88.47%
# [CrossEntropy] Epoch 13: Loss=190.5693, Accuracy=88.30%
# [CrossEntropy] Epoch 14: Loss=183.3498, Accuracy=88.73%
# [CrossEntropy] Epoch 15: Loss=177.1846, Accuracy=88.49%
# [CrossEntropy] Epoch 16: Loss=171.5799, Accuracy=88.46%
# [CrossEntropy] Epoch 17: Loss=163.4790, Accuracy=89.57%
# [CrossEntropy] Epoch 18: Loss=158.5369, Accuracy=89.20%
# [CrossEntropy] Epoch 19: Loss=152.4325, Accuracy=88.75%
# [CrossEntropy] Epoch 20: Loss=149.2767, Accuracy=88.92%
# [CrossEntropy] Epoch 21: Loss=146.1540, Accuracy=88.71%
# [CrossEntropy] Gradient Flow at Epoch 20
# [CrossEntropy] Activation Distribution at Epoch 20
# [CrossEntropy] Gradient Histogram at Epoch 20
# [CrossEntropy] Epoch 22: Loss=140.8873, Accuracy=88.88%
# [CrossEntropy] Epoch 23: Loss=132.6349, Accuracy=88.39%
# [CrossEntropy] Epoch 24: Loss=132.2376, Accuracy=88.56%
# [CrossEntropy] Epoch 25: Loss=126.1219, Accuracy=89.64%
# [CrossEntropy] Epoch 26: Loss=121.5438, Accuracy=88.87%
# [CrossEntropy] Epoch 27: Loss=120.9906, Accuracy=89.90%
# [CrossEntropy] Epoch 28: Loss=115.4069, Accuracy=89.74%
# [CrossEntropy] Epoch 29: Loss=112.6256, Accuracy=89.23%
# [CrossEntropy] Epoch 30: Loss=109.0688, Accuracy=89.48%
# [CrossEntropy] Epoch 31: Loss=108.1048, Accuracy=88.93%
# [CrossEntropy] Epoch 32: Loss=104.0336, Accuracy=89.54%
# [CrossEntropy] Epoch 33: Loss=102.4117, Accuracy=89.04%
# [CrossEntropy] Epoch 34: Loss=97.4765, Accuracy=89.16%
# [CrossEntropy] Epoch 35: Loss=94.7024, Accuracy=89.78%
# [CrossEntropy] Epoch 36: Loss=92.0342, Accuracy=89.30%
# [CrossEntropy] Epoch 37: Loss=89.9691, Accuracy=89.88%
# [CrossEntropy] Epoch 38: Loss=89.9679, Accuracy=89.28%
# [CrossEntropy] Epoch 39: Loss=84.3191, Accuracy=89.79%
# [CrossEntropy] Epoch 40: Loss=84.4798, Accuracy=89.27%
# [CrossEntropy] Gradient Flow at Epoch 39
# [CrossEntropy] Activation Distribution at Epoch 39
# [CrossEntropy] Gradient Histogram at Epoch 39
# [MSE] Epoch 1: Loss=25.5587, Accuracy=83.77%
# [MSE] Gradient Flow at Epoch 0
# [MSE] Activation Distribution at Epoch 0
# [MSE] Gradient Histogram at Epoch 0
# [MSE] Epoch 2: Loss=18.7729, Accuracy=83.72%
# [MSE] Epoch 3: Loss=17.2092, Accuracy=85.37%
# [MSE] Epoch 4: Loss=16.0136, Accuracy=86.06%
# [MSE] Epoch 5: Loss=15.1025, Accuracy=87.03%
# [MSE] Epoch 6: Loss=14.5073, Accuracy=88.11%
# [MSE] Epoch 7: Loss=13.8810, Accuracy=88.14%
# [MSE] Epoch 8: Loss=13.2984, Accuracy=88.25%
# [MSE] Epoch 9: Loss=12.8814, Accuracy=88.09%
# [MSE] Epoch 10: Loss=12.5180, Accuracy=88.52%
# [MSE] Epoch 11: Loss=12.2373, Accuracy=88.38%
# [MSE] Epoch 12: Loss=11.6750, Accuracy=88.28%
# [MSE] Epoch 13: Loss=11.3619, Accuracy=88.85%
# [MSE] Epoch 14: Loss=11.1968, Accuracy=88.85%
# [MSE] Epoch 15: Loss=10.9769, Accuracy=88.80%
# [MSE] Epoch 16: Loss=10.5570, Accuracy=88.86%
# [MSE] Epoch 17: Loss=10.2815, Accuracy=88.93%
# [MSE] Epoch 18: Loss=10.0991, Accuracy=88.95%
# [MSE] Epoch 19: Loss=9.7344, Accuracy=88.33%
# [MSE] Epoch 20: Loss=9.6537, Accuracy=88.88%
# [MSE] Epoch 21: Loss=9.5028, Accuracy=89.18%
# [MSE] Gradient Flow at Epoch 20
# [MSE] Activation Distribution at Epoch 20
# [MSE] Gradient Histogram at Epoch 20
# [MSE] Epoch 22: Loss=9.1175, Accuracy=89.13%
# [MSE] Epoch 23: Loss=9.0720, Accuracy=89.26%
# [MSE] Epoch 24: Loss=8.8054, Accuracy=89.31%
# [MSE] Epoch 25: Loss=8.5379, Accuracy=88.76%
# [MSE] Epoch 26: Loss=8.6178, Accuracy=88.77%
# [MSE] Epoch 27: Loss=8.1903, Accuracy=88.75%
# [MSE] Epoch 28: Loss=7.9280, Accuracy=88.35%
# [MSE] Epoch 29: Loss=7.9698, Accuracy=89.62%
# [MSE] Epoch 30: Loss=7.7802, Accuracy=89.04%
# [MSE] Epoch 31: Loss=7.6394, Accuracy=89.67%
# [MSE] Epoch 32: Loss=7.4865, Accuracy=88.74%
# [MSE] Epoch 33: Loss=7.3727, Accuracy=89.23%
# [MSE] Epoch 34: Loss=7.0412, Accuracy=89.14%
# [MSE] Epoch 35: Loss=7.2939, Accuracy=89.36%
# [MSE] Epoch 36: Loss=6.9984, Accuracy=89.35%
# [MSE] Epoch 37: Loss=6.7940, Accuracy=89.28%
# [MSE] Epoch 38: Loss=6.9355, Accuracy=89.12%
# [MSE] Epoch 39: Loss=6.5982, Accuracy=89.54%
# [MSE] Epoch 40: Loss=6.5932, Accuracy=89.36%
# [MSE] Gradient Flow at Epoch 39
# [MSE] Activation Distribution at Epoch 39
# [MSE] Gradient Histogram at Epoch 39
#  [Dead ReLU 비율] MSE 모델
#  [Dead ReLU 비율] CrossEntropy 모델
