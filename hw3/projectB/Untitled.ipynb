# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 🔹 데이터 생성 및 전처리
X, y = make_circles(n_samples=1000, factor=0.5, noise=0.1)
X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.long)
y_test = torch.tensor(y_test, dtype=torch.long)

train_loader = torch.utils.data.DataLoader(list(zip(X_train, y_train)), batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(list(zip(X_test, y_test)), batch_size=1000)

# 🔹 MLP 정의
class MLP(nn.Module):
    def __init__(self, activation='relu'):
        super(MLP, self).__init__()
        act_fn = self._get_activation(activation)
        self.activation_name = activation

        self.model = nn.Sequential(
            nn.Linear(2, 64),
            act_fn(),
            nn.Linear(64, 32),
            act_fn(),
            nn.Linear(32, 2)
        )
        self.model.apply(self._init_weights)

    def _get_activation(self, name):
        if name == 'relu':
            return nn.ReLU
        elif name == 'leakyrelu':
            return lambda: nn.LeakyReLU(0.01)
        elif name == 'sigmoid':
            return nn.Sigmoid
        else:
            raise ValueError("Unsupported activation function")

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, std=0.01)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        return self.model(x)

# 🔹 평가 함수
def evaluate(model):
    model.eval()
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = model(data)
            pred = output.argmax(dim=1)
            correct += (pred == target).sum().item()
    return 100. * correct / len(test_loader.dataset)

# 🔹 학습 함수
def train(model, loss_fn, optimizer, epochs=80, tag='', loader=None):
    train_losses, test_accuracies = [], []
    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for data, target in loader:
            optimizer.zero_grad()
            output = model(data)
            loss = loss_fn(output, target)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        
        train_losses.append(total_loss / len(loader))
        acc = evaluate(model)
        test_accuracies.append(acc)

        print(f"[{tag}] Epoch {epoch+1}: Loss={total_loss:.4f}, Accuracy={acc:.2f}%")
        
        if epoch in [0, 40, epochs-1]:
            visualize_hidden_activations(epoch, model, loader, 1)
            visualize_hidden_activations(epoch, model, loader, 3)
            print(f"[{tag}] Dead Neuron Heatmap at Epoch {epoch}")
            visualize_dead_neurons(model, loader, model.activation_name, tag=f"{tag}-Epoch{epoch}")
    
    return train_losses, test_accuracies

# 활성화 함수에 따른 dead neuron 비율 계산 함수
def dead_neuron_ratio(tensor, act_fn_name):
    if act_fn_name == 'relu':
        return (tensor <= 0).sum().item() / tensor.numel()
    elif act_fn_name == 'leakyrelu':
        # LeakyReLU는 음수도 통과되지만 거의 0에 가까운 값이 많음 → 동일 기준 사용
        return (tensor <= 0).sum().item() / tensor.numel()
    elif act_fn_name == 'sigmoid':
        # Sigmoid는 saturation zone (0.01 이하 또는 0.99 이상) 기준
        return ((tensor < 0.01) | (tensor > 0.99)).sum().item() / tensor.numel()
    else:
        return 0.0

# 히트맵으로 시각화 (모든 활성화 함수용)
def visualize_dead_neurons(model, loader, act_fn_name, tag=''):
    model.eval()
    with torch.no_grad():
        for data, _ in loader:
            x = data.view(data.size(0), -1)
            ratios = []
            for layer in model.model:
                x = layer(x)
                if isinstance(layer, (nn.ReLU, nn.LeakyReLU, nn.Sigmoid)):
                    ratio = dead_neuron_ratio(x, act_fn_name)
                    ratios.append(ratio)
            break  # 한 배치만 사용

    if ratios:
        plt.figure(figsize=(6, 2))
        plt.imshow([ratios], cmap="Reds", aspect='auto')
        plt.title(f"{tag} Dead Neuron Ratio (per Activation Layer)")
        plt.colorbar(label="Dead Neuron Ratio")
        plt.xticks(ticks=range(len(ratios)), labels=[f"Layer {i+1}" for i in range(len(ratios))])
        plt.yticks([])
        plt.tight_layout()
        plt.show()

# 🔹 중간 활성화 히스토그램
def visualize_hidden_activations(epoch, model, loader, layer_idx):
    model.eval()
    activations = []
    with torch.no_grad():
        for data, _ in loader:
            x = data
            for i, layer in enumerate(model.model):
                x = layer(x)
                if i == layer_idx:
                    activations.append(x.cpu().numpy())
                    break
    activations = np.concatenate(activations, axis=0)
    plt.hist(activations.flatten(), bins=100)
    plt.title(f'Layer {layer_idx} activation histogram at epoch {epoch}')
    plt.show()

# 🔁 실험 반복 실행 (ReLU, LeakyReLU, Sigmoid)
results = {}
for act in ['relu', 'leakyrelu', 'sigmoid']:
    print(f"\n========== Activation: {act.upper()} ==========")
    model = MLP(activation=act)
    loss_fn = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.01)
    losses, accs = train(model, loss_fn, optimizer, tag=act.upper(), loader=train_loader)
    results[act] = {'loss': losses, 'acc': accs}

# 🔎 성능 비교 그래프
epochs = range(1, len(next(iter(results.values()))['loss'])+1)
plt.figure(figsize=(14, 5))

# 🔹 Loss
plt.subplot(1, 2, 1)
for act in results:
    plt.plot(epochs, results[act]['loss'], label=act.upper())
plt.title("Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

# 🔹 Accuracy
plt.subplot(1, 2, 2)
for act in results:
    plt.plot(epochs, results[act]['acc'], label=act.upper())
plt.title("Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ========== Activation: RELU ==========
# [RELU] Epoch 1: Loss=7.4805, Accuracy=53.33%
# [RELU] Dead Neuron Heatmap at Epoch 0
# [RELU] Epoch 2: Loss=5.7381, Accuracy=83.00%
# [RELU] Epoch 3: Loss=3.6209, Accuracy=94.33%
# [RELU] Epoch 4: Loss=2.3048, Accuracy=96.33%
# [RELU] Epoch 5: Loss=1.3758, Accuracy=96.67%
# [RELU] Epoch 6: Loss=0.7954, Accuracy=98.67%
# [RELU] Epoch 7: Loss=0.4380, Accuracy=98.67%
# [RELU] Epoch 8: Loss=0.3239, Accuracy=97.67%
# [RELU] Epoch 9: Loss=0.2169, Accuracy=98.67%
# [RELU] Epoch 10: Loss=0.2090, Accuracy=98.33%
# [RELU] Epoch 11: Loss=0.1841, Accuracy=98.00%
# [RELU] Epoch 12: Loss=0.2154, Accuracy=98.00%
# [RELU] Epoch 13: Loss=0.1923, Accuracy=98.00%
# [RELU] Epoch 14: Loss=0.1053, Accuracy=98.00%
# [RELU] Epoch 15: Loss=0.0968, Accuracy=98.33%
# [RELU] Epoch 16: Loss=0.1406, Accuracy=98.00%
# [RELU] Epoch 17: Loss=0.1950, Accuracy=99.00%
# [RELU] Epoch 18: Loss=0.1028, Accuracy=97.67%
# [RELU] Epoch 19: Loss=0.1254, Accuracy=98.33%
# [RELU] Epoch 20: Loss=0.0810, Accuracy=98.67%
# [RELU] Epoch 69: Loss=0.0085, Accuracy=98.33%
# [RELU] Epoch 70: Loss=0.0087, Accuracy=98.33%
# [RELU] Epoch 71: Loss=0.0081, Accuracy=98.33%
# [RELU] Epoch 72: Loss=0.0089, Accuracy=98.33%
# [RELU] Epoch 73: Loss=0.0074, Accuracy=98.67%
# [RELU] Epoch 74: Loss=0.0072, Accuracy=98.33%
# [RELU] Epoch 75: Loss=0.0081, Accuracy=98.33%
# [RELU] Epoch 76: Loss=0.0070, Accuracy=98.33%
# [RELU] Epoch 77: Loss=0.0070, Accuracy=98.33%
# [RELU] Epoch 78: Loss=0.0082, Accuracy=98.67%
# [RELU] Epoch 79: Loss=0.0066, Accuracy=98.33%
# [RELU] Epoch 80: Loss=0.0070, Accuracy=98.33%
# [RELU] Dead Neuron Heatmap at Epoch 79
# ========== Activation: LEAKYRELU ==========
# [LEAKYRELU] Epoch 1: Loss=7.4103, Accuracy=52.67%
# [LEAKYRELU] Dead Neuron Heatmap at Epoch 0
# [LEAKYRELU] Epoch 2: Loss=5.0979, Accuracy=94.00%
# [LEAKYRELU] Epoch 3: Loss=2.4045, Accuracy=95.33%
# [LEAKYRELU] Epoch 4: Loss=0.9742, Accuracy=97.00%
# [LEAKYRELU] Epoch 5: Loss=0.4755, Accuracy=98.00%
# [LEAKYRELU] Epoch 6: Loss=0.2562, Accuracy=98.33%
# [LEAKYRELU] Epoch 7: Loss=0.1617, Accuracy=98.00%
# [LEAKYRELU] Epoch 8: Loss=0.2146, Accuracy=98.33%
# [LEAKYRELU] Epoch 9: Loss=0.1083, Accuracy=98.00%
# [LEAKYRELU] Epoch 10: Loss=0.0934, Accuracy=98.00%
# [LEAKYRELU] Epoch 11: Loss=0.0958, Accuracy=98.67%
# [LEAKYRELU] Epoch 12: Loss=0.0924, Accuracy=98.00%
# [LEAKYRELU] Epoch 13: Loss=0.0935, Accuracy=98.33%
# [LEAKYRELU] Epoch 14: Loss=0.1001, Accuracy=96.67%
# [LEAKYRELU] Epoch 15: Loss=0.2187, Accuracy=98.33%
# [LEAKYRELU] Epoch 16: Loss=0.2264, Accuracy=96.67%
# [LEAKYRELU] Epoch 17: Loss=0.1644, Accuracy=98.33%
# [LEAKYRELU] Epoch 18: Loss=0.1381, Accuracy=97.67%
# [LEAKYRELU] Epoch 19: Loss=0.1256, Accuracy=98.67%
# [LEAKYRELU] Epoch 20: Loss=0.0437, Accuracy=98.67%
# [LEAKYRELU] Epoch 21: Loss=0.0520, Accuracy=98.67%
# [LEAKYRELU] Epoch 22: Loss=0.0643, Accuracy=98.67%
# [LEAKYRELU] Epoch 23: Loss=0.0402, Accuracy=98.33%
# [LEAKYRELU] Epoch 24: Loss=0.0653, Accuracy=98.33%
# [LEAKYRELU] Epoch 25: Loss=0.0303, Accuracy=98.33%
# [LEAKYRELU] Epoch 26: Loss=0.0211, Accuracy=98.33%
# [LEAKYRELU] Epoch 27: Loss=0.0149, Accuracy=98.33%
# [LEAKYRELU] Epoch 28: Loss=0.0321, Accuracy=97.67%
# [LEAKYRELU] Epoch 29: Loss=0.1131, Accuracy=98.67%
# [LEAKYRELU] Epoch 30: Loss=0.0714, Accuracy=98.67%
# [LEAKYRELU] Epoch 31: Loss=0.0722, Accuracy=98.00%
# [LEAKYRELU] Epoch 32: Loss=0.0265, Accuracy=98.67%
# [LEAKYRELU] Epoch 33: Loss=0.0882, Accuracy=98.00%
# [LEAKYRELU] Epoch 34: Loss=0.0552, Accuracy=98.00%
# [LEAKYRELU] Epoch 35: Loss=0.0276, Accuracy=98.00%
# [LEAKYRELU] Epoch 36: Loss=0.0124, Accuracy=98.33%
# [LEAKYRELU] Epoch 37: Loss=0.0168, Accuracy=98.33%
# [LEAKYRELU] Epoch 38: Loss=0.0139, Accuracy=98.00%
# [LEAKYRELU] Epoch 39: Loss=0.0177, Accuracy=98.00%
# [LEAKYRELU] Epoch 40: Loss=0.1035, Accuracy=98.00%
# [LEAKYRELU] Epoch 41: Loss=0.1147, Accuracy=98.33%
# [LEAKYRELU] Dead Neuron Heatmap at Epoch 40
# [LEAKYRELU] Epoch 42: Loss=0.4400, Accuracy=96.33%
# [LEAKYRELU] Epoch 43: Loss=0.3495, Accuracy=97.00%
# [LEAKYRELU] Epoch 44: Loss=0.3690, Accuracy=99.00%
# [LEAKYRELU] Epoch 45: Loss=0.2229, Accuracy=97.00%
# [LEAKYRELU] Epoch 46: Loss=0.3340, Accuracy=97.00%
# [LEAKYRELU] Epoch 47: Loss=0.6042, Accuracy=97.33%
# [LEAKYRELU] Epoch 48: Loss=0.4694, Accuracy=97.00%
# [LEAKYRELU] Epoch 49: Loss=0.3985, Accuracy=97.33%
# [LEAKYRELU] Epoch 50: Loss=0.3725, Accuracy=97.67%
# [LEAKYRELU] Epoch 51: Loss=0.3795, Accuracy=97.67%
# [LEAKYRELU] Epoch 52: Loss=0.2277, Accuracy=98.67%
# [LEAKYRELU] Epoch 53: Loss=0.0627, Accuracy=98.67%
# [LEAKYRELU] Epoch 54: Loss=0.0465, Accuracy=98.33%
# [LEAKYRELU] Epoch 55: Loss=0.0585, Accuracy=98.33%
# [LEAKYRELU] Epoch 56: Loss=0.0697, Accuracy=98.33%
# [LEAKYRELU] Epoch 57: Loss=0.0624, Accuracy=98.33%
# [LEAKYRELU] Epoch 58: Loss=0.0295, Accuracy=98.33%
# [LEAKYRELU] Epoch 59: Loss=0.0219, Accuracy=98.33%
# [LEAKYRELU] Epoch 60: Loss=0.0273, Accuracy=98.67%
# [LEAKYRELU] Epoch 61: Loss=0.0220, Accuracy=98.67%
# [LEAKYRELU] Epoch 62: Loss=0.0173, Accuracy=98.33%
# [LEAKYRELU] Epoch 63: Loss=0.0188, Accuracy=98.67%
# [LEAKYRELU] Epoch 64: Loss=0.0142, Accuracy=98.67%
# [LEAKYRELU] Epoch 65: Loss=0.0138, Accuracy=98.67%
# [LEAKYRELU] Epoch 66: Loss=0.0120, Accuracy=98.33%
# [LEAKYRELU] Epoch 67: Loss=0.0138, Accuracy=98.33%
# [LEAKYRELU] Epoch 68: Loss=0.0106, Accuracy=98.67%
# [LEAKYRELU] Epoch 69: Loss=0.0111, Accuracy=98.33%
# [LEAKYRELU] Epoch 70: Loss=0.0123, Accuracy=98.67%
# [LEAKYRELU] Epoch 71: Loss=0.0107, Accuracy=98.33%
# [LEAKYRELU] Epoch 72: Loss=0.0106, Accuracy=98.33%
# [LEAKYRELU] Epoch 73: Loss=0.0133, Accuracy=98.00%
# [LEAKYRELU] Epoch 74: Loss=0.0085, Accuracy=98.67%
# [LEAKYRELU] Epoch 75: Loss=0.0086, Accuracy=98.33%
# [LEAKYRELU] Epoch 76: Loss=0.0071, Accuracy=98.33%
# [LEAKYRELU] Epoch 77: Loss=0.0075, Accuracy=98.33%
# [LEAKYRELU] Epoch 78: Loss=0.0081, Accuracy=98.33%
# [LEAKYRELU] Epoch 79: Loss=0.0067, Accuracy=98.67%
# [LEAKYRELU] Epoch 80: Loss=0.0068, Accuracy=98.67%
# [LEAKYRELU] Dead Neuron Heatmap at Epoch 79
# ========== Activation: SIGMOID ==========
# [SIGMOID] Epoch 1: Loss=7.6682, Accuracy=51.00%
# [SIGMOID] Dead Neuron Heatmap at Epoch 0
# [SIGMOID] Epoch 2: Loss=7.6212, Accuracy=49.00%
# [SIGMOID] Epoch 3: Loss=7.6331, Accuracy=49.00%
# [SIGMOID] Epoch 4: Loss=7.6332, Accuracy=49.00%
# [SIGMOID] Epoch 5: Loss=7.6267, Accuracy=51.00%
# [SIGMOID] Epoch 6: Loss=7.6243, Accuracy=49.00%
# [SIGMOID] Epoch 7: Loss=7.6246, Accuracy=49.00%
# [SIGMOID] Epoch 8: Loss=7.6276, Accuracy=49.00%
# [SIGMOID] Epoch 9: Loss=7.6266, Accuracy=49.00%
# [SIGMOID] Epoch 10: Loss=7.6252, Accuracy=49.00%
# [SIGMOID] Epoch 11: Loss=7.6292, Accuracy=49.00%
# [SIGMOID] Epoch 12: Loss=7.6291, Accuracy=49.00%
# [SIGMOID] Epoch 13: Loss=7.6264, Accuracy=49.00%
# [SIGMOID] Epoch 14: Loss=7.6247, Accuracy=49.00%
# [SIGMOID] Epoch 15: Loss=7.6273, Accuracy=49.00%
# [SIGMOID] Epoch 16: Loss=7.6270, Accuracy=49.00%
# [SIGMOID] Epoch 17: Loss=7.6255, Accuracy=49.00%
# [SIGMOID] Epoch 18: Loss=7.6286, Accuracy=49.00%
# [SIGMOID] Epoch 19: Loss=7.6231, Accuracy=49.00%
# [SIGMOID] Epoch 20: Loss=7.6306, Accuracy=51.00%
# [SIGMOID] Epoch 21: Loss=7.6261, Accuracy=49.00%
# [SIGMOID] Epoch 22: Loss=7.6254, Accuracy=49.00%
# [SIGMOID] Epoch 23: Loss=7.6258, Accuracy=49.00%
# [SIGMOID] Epoch 24: Loss=7.6265, Accuracy=49.00%
# [SIGMOID] Epoch 25: Loss=7.6281, Accuracy=51.00%
# [SIGMOID] Epoch 26: Loss=7.6269, Accuracy=49.00%
# [SIGMOID] Epoch 27: Loss=7.6250, Accuracy=49.00%
# [SIGMOID] Epoch 28: Loss=7.6253, Accuracy=49.00%
# [SIGMOID] Epoch 29: Loss=7.6263, Accuracy=49.00%
# [SIGMOID] Epoch 30: Loss=7.6253, Accuracy=49.00%
# [SIGMOID] Epoch 31: Loss=7.6256, Accuracy=49.00%
# [SIGMOID] Epoch 32: Loss=7.6262, Accuracy=49.00%
# [SIGMOID] Epoch 33: Loss=7.6278, Accuracy=49.00%
# [SIGMOID] Epoch 34: Loss=7.6311, Accuracy=49.00%
# [SIGMOID] Epoch 35: Loss=7.6290, Accuracy=49.00%
# [SIGMOID] Epoch 36: Loss=7.6272, Accuracy=51.00%
